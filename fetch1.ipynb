# %%
import requests
import json
import time

# %%
headers={"Authorization":"Bearer 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"}


def download(url):
    res=None
    for times in range(3):
        try:
            res=requests.get(url,headers=headers)
            if res.status_code==200:
                return [True,res.json()]
        except:
            continue
    return [False,res.content]

# %%
# 一开始爬取到45页发现失败掉了。因为触发了API速率限制（非认证请求60/h）。
# 所以后来在headers加上了自己的tocken认证
for index in range(45,100):
    time.sleep(3)
    url=f'https://api.github.com/repos/vacanza/python-holidays/issues?state=all&page={index}'
    d_ok,res_json=download(url)
    if not d_ok:
        print(f'failed to get page {index}')
        exit(1)
    if len(res_json)==0:
        break
    fp=f'D:/jsons/{index}.json'
    json.dump(res_json,open(fp,'w+'))
    print(f'successfully got page {index}')
print('finished')
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[3], line 13
#      11         break
#      12     fp=f'D:/jsons/{index}.json'
# ---> 13     json.dump(res_json,open(fp,'w+'))
#      14     print(f'successfully got page {index}')
#      15 print('finished')
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\IPython\core\interactiveshell.py:308, in _modified_open(file, *args, **kwargs)
#     301 if file in {0, 1, 2}:
#     302     raise ValueError(
#     303         f"IPython won't let you open fd={file} by default "
#     304         "as it is likely to crash IPython. If you know what you are doing, "
#     305         "you can use builtins' open."
#     306     )
# --> 308 return io_open(file, *args, **kwargs)
#
# FileNotFoundError: [Errno 2] No such file or directory: 'D:/jsons/45.json'

# %%
file_num=56 #文件总数
count_one=0
for index in range(1,file_num+1):
    fp=f'jsons/{index}.json'
    data=json.load(open(fp,'r',encoding='utf-8'))
    for node in data:
        if node['node_id'].startswith('I_'): #筛选Issue
            if '-01-' in node['created_at']: 
                #print(node['created_at'])
                count_one+=1
print(count_one)
#二月
count_two=0
for index in range(1,file_num+1):
    fp=f'jsons/{index}.json'
    data=json.load(open(fp,'r',encoding='utf-8'))
    for node in data:
        if node['node_id'].startswith('I_'): #筛选Issue
            if '-02-' in node['created_at']: 
                #print(node['created_at'])
                count_two+=1
print(count_two)
#三月
count_three=0
for index in range(1,file_num+1):
    fp=f'jsons/{index}.json'
    data=json.load(open(fp,'r',encoding='utf-8'))
    for node in data:
        if node['node_id'].startswith('I_'): #筛选Issue
            if '-03-' in node['created_at']: 
                #print(node['created_at'])
                count_three+=1
print(count_three)
#四月
count_four=0
for index in range(1,file_num+1):
    fp=f'jsons/{index}.json'
    data=json.load(open(fp,'r',encoding='utf-8'))
    for node in data:
        if node['node_id'].startswith('I_'): #筛选Issue
            if '-04-' in node['created_at']: 
                #print(node['created_at'])
                count_four+=1
print(count_four)
#五月
count_five=0
for index in range(1,file_num+1):
    fp=f'jsons/{index}.json'
    data=json.load(open(fp,'r',encoding='utf-8'))
    for node in data:
        if node['node_id'].startswith('I_'): #筛选Issue
            if '-05-' in node['created_at']: 
                #print(node['created_at'])
                count_five+=1
print(count_five)
#六月
count_six=0
for index in range(1,file_num+1):
    fp=f'jsons/{index}.json'
    data=json.load(open(fp,'r',encoding='utf-8'))
    for node in data:
        if node['node_id'].startswith('I_'): #筛选Issue
            if '-06-' in node['created_at']: 
                #print(node['created_at'])
                count_six+=1
print(count_six)
#七月
count_seven=0
for index in range(1,file_num+1):
    fp=f'jsons/{index}.json'
    data=json.load(open(fp,'r',encoding='utf-8'))
    for node in data:
        if node['node_id'].startswith('I_'): #筛选Issue
            if '-07-' in node['created_at']: 
                #print(node['created_at'])
                count_seven+=1
print(count_seven)
#八月
count_eight=0
for index in range(1,file_num+1):
    fp=f'jsons/{index}.json'
    data=json.load(open(fp,'r',encoding='utf-8'))
    for node in data:
        if node['node_id'].startswith('I_'): #筛选Issue
            if '-08-' in node['created_at']: 
                #print(node['created_at'])
                count_eight+=1
print(count_eight)
#九月
count_nine=0
for index in range(1,file_num+1):
    fp=f'jsons/{index}.json'
    data=json.load(open(fp,'r',encoding='utf-8'))
    for node in data:
        if node['node_id'].startswith('I_'): #筛选Issue
            if '-09-' in node['created_at']: 
                #print(node['created_at'])
                count_nine+=1
print(count_nine)
#十月
count_ten=0
for index in range(1,file_num+1):
    fp=f'jsons/{index}.json'
    data=json.load(open(fp,'r',encoding='utf-8'))
    for node in data:
        if node['node_id'].startswith('I_'): #筛选Issue
            if '-10-' in node['created_at']: 
                #print(node['created_at'])
                count_ten+=1
print(count_ten)
#十一月
count_nov=0
for index in range(1,file_num+1):
    fp=f'jsons/{index}.json'
    data=json.load(open(fp,'r',encoding='utf-8'))
    for node in data:
        if node['node_id'].startswith('I_'): #筛选Issue
            if '-11-' in node['created_at']: 
                #print(node['created_at'])
                count_nov+=1
print(count_nov)
#十二月
count_dec=0
for index in range(1,file_num+1):
    fp=f'jsons/{index}.json'
    data=json.load(open(fp,'r',encoding='utf-8'))
    for node in data:
        if node['node_id'].startswith('I_'): #筛选Issue
            if '-12-' in node['created_at']: 
                #print(node['created_at'])
                count_dec+=1
print(count_dec)
#后面的单元格我没有修改
#yc已修改

L2 = [count_one,count_two,count_three,count_four,count_five,count_six,count_seven,count_eight,count_nine,count_ten,count_nov,count_dec]
L1 = ['一月','二月','三月','四月','五月','六月','七月','八月','九月','十月','十一月','十二月']



from plotly import offline

# 可视化
data = [{
    'type': 'bar',
    'x': L1,
    'y': L2,   
    'marker': {
        'color': 'rgb(100, 140, 200)',
        'line': {'width': 5, 'color': 'rgb(145, 30, 12)'}
    },
    'opacity': 0.3,
}]

my_layout = {
    'title': 'issue创建月份调查',
    'titlefont': {'size': 20},
    'xaxis': {
        'title': 'issue month',
        'titlefont': {'size': 20},
        'tickfont': {'size': 10},
    },
    'yaxis': {
        'title': '问题数量',
        'titlefont': {'size': 20},
        'tickfont': {'size': 10},
    },

}

fig = {'data': data, 'layout': my_layout}
offline.plot(fig, filename='month_issue.html')
# Out:
# 29
# 22
# 13
# 11
# 71
# 37
# 9
# 8
# 30
# 16
# 26
# 17
# 'month_issue.html'
